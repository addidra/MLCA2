# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("ML_CA2_Responses - Form Responses 1.csv")
df
# Out:
#              Timestamp                  Email Address  \
# 0    1/7/2024 21:54:56       aishahstyles28@gmail.com
# 1    1/7/2024 21:56:44             wase7523@gmail.com
# 2    1/7/2024 22:02:45    hemangisarangdhar@gmail.com
# 3    1/7/2024 22:50:25     khan.daniya16994@gmail.com
# 4   1/10/2024 12:05:42       fauziasuhani23@gmail.com
# 5   1/11/2024 12:32:38     priyachandwani84@gmail.com
# 6    1/12/2024 9:14:31    ahammad.aqib09939@gmail.com
# 7    1/12/2024 9:26:06             maacm580@gmail.com
# 8    1/12/2024 9:36:15    thunderstruck9999@gmail.com
# 9    1/12/2024 9:38:33         ahammad78605@gmail.com
# 10  1/12/2024 10:34:13  engineer.ammar18724@gmail.com
#
#     Please provide your age. What is your current occupation?  \
# 0                         20                         Student
# 1                         20         Unemployed but ambitious
# 2                         20                         Student
# 3                         20                          Student
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 14 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Timestamp                                                                                                11 non-null     object
#  1   Email Address                                                                                            11 non-null     object
#  2   Please provide your age.                                                                                 11 non-null     int64
#  3   What is your current occupation?                                                                         11 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                  0
# Email Address                                                                                              0
# Please provide your age.                                                                                   0
# What is your current occupation?                                                                           0
# Where is your current place of residence?                                                                  0
# On a scale of 1 to 10, how satisfied are you with your current place of residence?                         0
# What factors would most likely influence you to move to a different location?                              0
# How satisfied are you with the community and neighborhood amenities in your current location?              0
# What amenities do you believe are lacking in your current community?                                       0
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Email Address', 'Please provide your age.',
#        'What is your current occupation?',
#        'Where is your current place of residence?',
#        'On a scale of 1 to 10, how satisfied are you with your current place of residence?',
#        'What factors would most likely influence you to move to a different location?',
#        'How satisfied are you with the community and neighborhood amenities in your current location?',
#        'What amenities do you believe are lacking in your current community?',
#        'To what extent does the environmental friendliness of a location influence your decision to move?',
#        'What specific environmental factors are important to you when choosing a place to live?',
#        'How would you rate your current financial stability?',
#        'If your job allows for remote work, how likely are you to consider moving to a location of your choice?',
# ...

# %%
x=df[['What is your current occupation?','On a scale of 1 to 10, how satisfied are you with your current place of residence?','How satisfied are you with the community and neighborhood amenities in your current location?','To what extent does the environmental friendliness of a location influence your decision to move?','How would you rate your current financial stability?','If your job allows for remote work, how likely are you to consider moving to a location of your choice?']]

# %%
x
# Out:
#    What is your current occupation?  \
# 0                          Student
# 1          Unemployed but ambitious
# 2                          Student
# 3                           Student
# 4                          Teacher
# 5                           Student
# 6                          Student
# 7                            Doctor
# 8                             Study
# 9                       Social work
# 10                          Student
#
#     On a scale of 1 to 10, how satisfied are you with your current place of residence?  \
# 0                                                   5
# 1                                                   9
# 2                                                   9
# 3                                                  10
# 4                                                   7
# 5                                                  10
# 6                                                   4
# 7                                                   7
# ...

# %%
x.describe()
# Out:
#        On a scale of 1 to 10, how satisfied are you with your current place of residence?  \
# count                                          11.000000
# mean                                            7.363636
# std                                             2.377929
# min                                             4.000000
# 25%                                             5.500000
# 50%                                             7.000000
# 75%                                             9.500000
# max                                            10.000000
#
#        How satisfied are you with the community and neighborhood amenities in your current location?  \
# count                                          11.000000
# mean                                            6.272727
# std                                             2.611165
# min                                             2.000000
# 25%                                             4.500000
# ...

# %%
df.describe()
# Out:
#        Please provide your age.  \
# count                 11.000000
# mean                  27.454545
# std                   14.376117
# min                   19.000000
# 25%                   20.000000
# 50%                   20.000000
# 75%                   26.000000
# max                   62.000000
#
#        On a scale of 1 to 10, how satisfied are you with your current place of residence?  \
# count                                          11.000000
# mean                                            7.363636
# std                                             2.377929
# min                                             4.000000
# 25%                                             5.500000
# 50%                                             7.000000
# 75%                                             9.500000
# max                                            10.000000
#
#        How satisfied are you with the community and neighborhood amenities in your current location?  \
# ...

# %%
labelEncoder = LabelEncoder()
print(df['Influence to Relocate'])
print("-----------------------------")
df['Numeric Influence to Relocate'] = labelEncoder.fit_transform(df['Influence to Relocate'])
print(df['Numeric Influence to Relocate'])
# Out:
# 0                         Job Opportunities, Education
# 1    Job Opportunities, Climate, Geographical Location
# 2                         Job Opportunities, Education
# 3                                       Cost Of Living
# 4         Job Opportunities, Safety, Family, Education
# 5                           Job Opportunities, Climate
# 6    Job Opportunities, Climate, Education, Geograp...
# 7    Job Opportunities, Cost Of Living, Climate, Sa...
# 8    Cost Of Living, Safety, Education, Geographica...
# 9                                       Cost Of Living
# Name: Influence to Relocate, dtype: object
# -----------------------------
# 0    6
# 1    4
# 2    6
# 3    0
# 4    7
# 5    2
# 6    3
# 7    5
# 8    1
# 9    0
# Name: Numeric Influence to Relocate, dtype: int64

# %%
mean = df['Age'].mean()
mean
# Out:
# 28.2
