# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/content/sample_data/ML_CA2_Responses - Form Responses 1.csv")
df
# Out:
#    Age                Occupation    Residence  \
# 0   20                  Student       Mumbai
# 1   20  Unemployed but ambitious    Mira Road
# 2   20                  Student        Mumbai
# 3   20                   Student       Mumbai
# 4   26                  Teacher       Mumbai
# 5   20                   Student  Ulhasnagar
# 6   19                  Student       Mumbai
# 7   26                    Doctor   Mira Road
# 8   49                     Study      Mumbai
# 9   62               Social work    Mira Road
#
#    Current Location Satisfaction Level  \
# 0                                    5
# 1                                    9
# 2                                    9
# 3                                   10
# 4                                    7
# 5                                   10
# 6                                    4
# 7                                    7
# 8                                    4
# 9                                   10
#
# ...

# %%
labelEncoder = LabelEncoder()
print(df['Influence to Relocate'])
print("-----------------------------")
df['Numeric Influence to Relocate'] = labelEncoder.fit_transform(df['Influence to Relocate'])
print(df['Numeric Influence to Relocate'])
# Out:
# 0                         Job Opportunities, Education
# 1    Job Opportunities, Climate, Geographical Location
# 2                         Job Opportunities, Education
# 3                                       Cost Of Living
# 4         Job Opportunities, Safety, Family, Education
# 5                           Job Opportunities, Climate
# 6    Job Opportunities, Climate, Education, Geograp...
# 7    Job Opportunities, Cost Of Living, Climate, Sa...
# 8    Cost Of Living, Safety, Education, Geographica...
# 9                                       Cost Of Living
# Name: Influence to Relocate, dtype: object
# -----------------------------
# 0    6
# 1    4
# 2    6
# 3    0
# 4    7
# 5    2
# 6    3
# 7    5
# 8    1
# 9    0
# Name: Numeric Influence to Relocate, dtype: int64

# %%
mean = df['Age'].mean()
mean
# Out:
# 28.2
